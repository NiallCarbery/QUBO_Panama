# %%
import sys
import os

# Add the path to the code directory to the system path
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath("."), '../code')))

from run import iteration_run, plot
from parameters import *

# %%
# Size of List to Simualte
testing_sample = list(range(2, 26, 2))
instance_sizes, best_water_costs, baseline_costs = iteration_run(testing_sample, NUM_READS=50)
# Out:
# Instance with 2 ships (and 2 time slots):
#   Optimized total water cost = 75
#   Baseline total water cost   = 75
#   Number of feasible solutions: 49
#   Number of infeasible solutions: 1
#   Tandem lockages used: 0
#   Cross fills applied: 0
#   Length of ships: [303.92 275.93]
#   Benefit of ships: [6.5 6.5]
#   Infeasibility reasons: [['Ship assigned 0 times (Expected 1).']]
#   Timetable for best solution:
#
# Timetable by Time Slot:
#   Time slot 1 (Lock type: Panamax_A): Ships [2]
#   Time slot 2 (Lock type: NeoPanamax): Ships [1]
#
# --------------------------------------------------
#
# Instance with 4 ships (and 4 time slots):
#   Optimized total water cost = 129.0
#   Baseline total water cost   = 150
#   Number of feasible solutions: 50
#   Number of infeasible solutions: 0
#   Tandem lockages used: 0
#   Cross fills applied: 1
#   Length of ships: [325.75 186.65 155.61 241.52]
#   Benefit of ships: [6.5 5.7 5.  6.1]
#   Timetable for best solution:
#
# ...

# %%
plot(instance_sizes, best_water_costs, baseline_costs)
